# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#sns.set_style("whitegrid")
#plt.style.use("fivethirtyeight")

happiness = pd.read_csv('World Happiness Report\\world-happiness-report-2021.csv')
happiness = happiness[["Country name", "Ladder score", "Logged GDP per capita", "Social support", "Healthy life expectancy", "Freedom to make life choices", "Generosity", "Perceptions of corruption"]]
happiness.head(33)
# Out:
#                 Country name  Ladder score  Logged GDP per capita  \
# 0                    Finland         7.842                 10.775
# 1                    Denmark         7.620                 10.933
# 2                Switzerland         7.571                 11.117
# 3                    Iceland         7.554                 10.878
# 4                Netherlands         7.464                 10.932
# 5                     Norway         7.392                 11.053
# 6                     Sweden         7.363                 10.867
# 7                 Luxembourg         7.324                 11.647
# 8                New Zealand         7.277                 10.643
# 9                    Austria         7.268                 10.906
# 10                 Australia         7.183                 10.796
# 11                    Israel         7.157                 10.575
# 12                   Germany         7.155                 10.873
# ...

# %%
from matplotlib.backends.backend_pdf import PdfPages

with PdfPages(r'C:\Users\leoma\Desktop\jupyter projects\scatterplot.pdf') as export_pdf:

    plt.scatter(happiness['Ladder score'], happiness['Logged GDP per capita'], color='red')
    #plt.title('Ladder score VS Logged GDP per capita', fontsize=14)
    plt.xlabel('Ladder score', fontsize=14)
    plt.ylabel('Logged GDP per capita', fontsize=14)
    plt.grid(True)
    #plt.show()
    export_pdf.savefig()
    plt.close()

# %%
# only gdp as input
import pandas as pd
import statsmodels.api as sm

X = happiness['Logged GDP per capita'] 
y = happiness['Ladder score']

X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X)
fitted = model.fit()



 
print_model = fitted.summary()
print(print_model)

#predictions = model.predict(X) 
#plt.plot(X, predictions)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Ladder score   R-squared:                       0.624
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     243.7
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):           5.23e-33
# Time:                        16:27:38   Log-Likelihood:                -148.73
# No. Observations:                 149   AIC:                             301.5
# Df Residuals:                     147   BIC:                             307.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -1.3719      0.446     -3.079      0.002      -2.253      -0.491
# ...

# %%
#data points vs predicted function - TODO: doesnt work? :C
"""
fig, ax = plt.subplots()
ax.scatter(X, y, alpha=0.5, color='orchid')
fig.suptitle('Scatter Plot')
fig.tight_layout(pad=2); 
ax.grid(True)
""""
# Out:
#   File "<ipython-input-4-3573d46667a7>", line 8
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
#more values as input
import pandas as pd
import statsmodels.api as sm

X = happiness[['Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]
y = happiness['Ladder score']

X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Ladder score   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.746
# Method:                 Least Squares   F-statistic:                     73.27
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):           5.06e-41
# Time:                        16:27:58   Log-Likelihood:                -116.50
# No. Observations:                 149   AIC:                             247.0
# Df Residuals:                     142   BIC:                             268.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           -2.2372      0.630     -3.548      0.001      -3.484      -0.991
# ...

# %%
#sns.pairplot(happiness)

pp = sns.pairplot(data=happiness,
                  x_vars=['Ladder score'],
                  y_vars=['Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption'])
